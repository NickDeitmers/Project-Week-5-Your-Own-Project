# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from string import ascii_letters

# %% [markdown]
# # Suicide

# %%
suicide = pd.read_csv("datasets/suicide.csv")

# %%
suicide.head(5)
# Out:
#    Unnamed: 0  country  year     sex          age  suicides_no  population  \
# 0          72  Albania  1995    male  25-34 years           13      232900
# 1          73  Albania  1995    male  55-74 years            9      178000
# 2          74  Albania  1995  female    75+ years            2       40800
# 3          75  Albania  1995  female  15-24 years           13      283500
# 4          76  Albania  1995    male  15-24 years           11      241200
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               5.58  Albania1995         0.619      2,424,499,009
# 1               5.06  Albania1995         0.619      2,424,499,009
# 2               4.90  Albania1995         0.619      2,424,499,009
# 3               4.59  Albania1995         0.619      2,424,499,009
# 4               4.56  Albania1995         0.619      2,424,499,009
#
#    gdp_per_capita ($)       generation
# 0                 835     Generation X
# ...

# %% [markdown]
# # Temperature

# %%
temperature = pd.read_csv("datasets/temperature_per_year.csv")

# %%
temperature.head(5)
# Out:
#    Unnamed: 0  Country  Year  AvgTemperature
# 0           0  Albania  1997       22.185990
# 1           1  Albania  1998       16.451389
# 2           2  Albania  1999       17.287201
# 3           3  Albania  2000       17.320525
# 4           4  Albania  2001       16.242000

# %% [markdown]
# # Military expenses

# %%
military = pd.read_csv("datasets/military_expenditures.csv")

# %%
military.head(5)
# Out:
#    Unnamed: 0 Country Name Country Code                   Indicator Name  \
# 0           0       Angola          AGO  Military expenditure (% of GDP)
# 1           1      Albania          ALB  Military expenditure (% of GDP)
# 2           2   Arab World          ARB  Military expenditure (% of GDP)
# 3           3    Argentina          ARG  Military expenditure (% of GDP)
# 4           4      Armenia          ARM  Military expenditure (% of GDP)
#
#        1995      1996      1997      1998       1999      2000  ...      2004  \
# 0  4.707393  2.447848  5.972268  2.642012  17.334692  6.392603  ...  3.471180
# 1  2.053587  1.379030  1.283081  1.238243   1.249210  1.246360  ...  1.381158
# 2  6.600877  6.019910  6.575124  7.545754   6.520144  6.416985  ...  5.076464
# 3  1.473073  1.241227  1.140139  1.136318   1.220360  1.148823  ...  0.883295
# 4  4.059312  3.281867  3.909399  3.528096   3.697374  3.560025  ...  2.741997
#
# ...

# %% [markdown]
# # Non grouped: Suicide x Temperature

# %%
suicide_temperature = pd.read_csv('datasets/suicide_and_avgtemp2.csv')

# %%
suicide_temperature.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  country  year     sex          age  suicides_no  \
# 0           0             0  Albania  1997    male  25-34 years           36
# 1           1             1  Albania  1997    male  15-24 years           33
# 2           2             2  Albania  1997    male    75+ years            3
# 3           3             3  Albania  1997    male  35-54 years           30
# 4           4             4  Albania  1997  female  15-24 years           21
#
#    population  suicides/100k pop  HDI for year  gdp_for_year ($)   \
# 0      236000              15.25           NaN      2,359,903,108
# 1      244400              13.50           NaN      2,359,903,108
# 2       25400              11.81           NaN      2,359,903,108
# 3      380800               7.88           NaN      2,359,903,108
# 4      294000               7.14           NaN      2,359,903,108
#
#    gdp_per_capita ($)  AvgTemperature higher/lower
# 0                 793        22.18599       higher
# ...

# %% [markdown]
# # Grouped: Suicide x Temperature

# %%
temp_x_suic = pd.read_csv("datasets/suicide_x_temperature.csv")

# %%
temp_x_suic.groupby(["Country"])["AvgTemperature", "suicides/100k pop"].mean().corr()
# Out:
# <ipython-input-259-0a20df3b13d2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   temp_x_suic.groupby(["Country"])["AvgTemperature", "suicides/100k pop"].mean().corr()
#                    AvgTemperature  suicides/100k pop
# AvgTemperature           1.000000          -0.443441
# suicides/100k pop       -0.443441           1.000000

# %%
temp_x_suic
# Out:
#       Unnamed: 0  Unnamed: 0.1     Country  Year  AvgTemperature  \
# 0              0             0     Albania  1997       22.185990
# 1              1             1     Albania  1998       16.451389
# 2              2             2     Albania  1999       17.287201
# 3              3             3     Albania  2000       17.320525
# 4              4             4     Albania  2001       16.242000
# ...          ...           ...         ...   ...             ...
# 1059        1059          2954  Uzbekistan  2009       16.127289
# 1060        1060          2955  Uzbekistan  2010       16.824810
# 1061        1061          2956  Uzbekistan  2011       15.813851
# 1062        1062          2957  Uzbekistan  2012       14.965695
# 1063        1063          2958  Uzbekistan  2013       16.268950
#
#       suicides/100k pop
# 0                 77.43
# 1                 66.52
# 2                 69.81
# 3                 30.70
# 4                 50.62
# ...                 ...
# ...

# %% [markdown]
# # Suicide x Temperature x Military Expenses

# %%
temp_suic_milit = pd.read_csv("datasets/temp_suic_milit.csv")

# %%
temp_suic_milit
# Out:
#     Unnamed: 0         Country  AvgTemperature  suicides/100k pop  \
# 0            0         Albania       16.903194          47.152857
# 1            1       Argentina       17.017071         121.882632
# 2            2       Australia       16.914340         147.381667
# 3            3         Austria       10.591614         254.554737
# 4            4         Bahrain       27.276898          22.948235
# 5            5         Belarus        7.483335         394.885333
# 6            6         Belgium       10.737883         239.524737
# 7            7          Brazil       22.089507          72.032105
# 8            8        Bulgaria       10.731872         205.872778
# 9            9          Canada        6.806418         138.638421
# 10          10        Colombia       13.391235          72.660000
# 11          11      Costa Rica       22.642378          87.216316
# 12          12         Croatia       12.249150         278.445556
# ...

# %%
other = suicide.groupby(["country"])["HDI for year", "gdp_per_capita ($)"].mean()
# Out:
# <ipython-input-344-b254206bb1cb>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   other = suicide.groupby(["country"])["HDI for year", "gdp_per_capita ($)"].mean()

# %% [markdown]
# # Everything per Country

# %%
complete_df = temp_suic_milit.merge(right = other, left_on = "Country", right_on = "country", how = "inner")

# %%
complete_df.corr()
# Out:
#                     Unnamed: 0  AvgTemperature  suicides/100k pop  \
# Unnamed: 0            1.000000        0.138957          -0.011302
# AvgTemperature        0.138957        1.000000          -0.504124
# suicides/100k pop    -0.011302       -0.504124           1.000000
# military_exp          0.106395        0.418784          -0.219168
# HDI for year         -0.118194       -0.465050           0.162634
# gdp_per_capita ($)   -0.012101       -0.366623           0.009131
#
#                     military_exp  HDI for year  gdp_per_capita ($)
# Unnamed: 0              0.106395     -0.118194           -0.012101
# AvgTemperature          0.418784     -0.465050           -0.366623
# suicides/100k pop      -0.219168      0.162634            0.009131
# military_exp            1.000000      0.048342           -0.000495
# HDI for year            0.048342      1.000000            0.862069
# gdp_per_capita ($)     -0.000495      0.862069            1.000000

# %%
complete_df
# Out:
#     Unnamed: 0         Country  AvgTemperature  suicides/100k pop  \
# 0            0         Albania       16.903194          47.152857
# 1            1       Argentina       17.017071         121.882632
# 2            2       Australia       16.914340         147.381667
# 3            3         Austria       10.591614         254.554737
# 4            4         Bahrain       27.276898          22.948235
# 5            5         Belarus        7.483335         394.885333
# 6            6         Belgium       10.737883         239.524737
# 7            7          Brazil       22.089507          72.032105
# 8            8        Bulgaria       10.731872         205.872778
# 9            9          Canada        6.806418         138.638421
# 10          10        Colombia       13.391235          72.660000
# 11          11      Costa Rica       22.642378          87.216316
# 12          12         Croatia       12.249150         278.445556
# ...

# %% [markdown]
# # EVERYTHING DATAFRAME

# %%
everything.head(5)
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1997    male  25-34 years           36      236000
# 1  Albania  1997    male  15-24 years           33      244400
# 2  Albania  1997    male    75+ years            3       25400
# 3  Albania  1997    male  35-54 years           30      380800
# 4  Albania  1997  female  15-24 years           21      294000
#
#    suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 0              15.25           NaN      2,359,903,108                 793
# 1              13.50           NaN      2,359,903,108                 793
# 2              11.81           NaN      2,359,903,108                 793
# 3               7.88           NaN      2,359,903,108                 793
# 4               7.14           NaN      2,359,903,108                 793
#
#    AvgTemperature higher/lower  military_exp
# 0        22.18599       higher      5.972268
# 1        22.18599       higher      5.972268
# ...

# %% [markdown]
# # Eventual DataFrame

# %%
data = pd.read_csv("datasets/dataproject4.csv")

# %%
data.groupby(['country'])['suicides/100k pop', 'AvgTemperature'].mean().sort_values(by = 'AvgTemperature', ascending = True)
# Out:
# <ipython-input-663-c157b905feb0>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['country'])['suicides/100k pop', 'AvgTemperature'].mean().sort_values(by = 'AvgTemperature', ascending = True)
#                 suicides/100k pop  AvgTemperature
# country
# Norway                 142.758824        5.459214
# Finland                241.734706        6.079014
# Canada                 135.748235        6.863614
# Latvia                 343.261176        7.467606
# Sweden                 158.977647        7.582139
# Belarus                389.504615        7.655202
# Denmark                161.211176        8.505147
# Czech Republic         202.166471        8.840170
# Poland                 184.751333        8.947929
# Ukraine                317.860625        9.006784
# Ireland                135.080000        9.761674
# Kazakhstan             373.495294        9.871606
# ...
